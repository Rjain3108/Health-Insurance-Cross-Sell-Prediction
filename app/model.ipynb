# %%
import pandas as pd

# %%
##import the train and test datasets

train_path = "/Users/rishabhjain/Documents/Bits-Pilani/Sem2/SEML/Health-Insurance-Cross-Sell-Prediction/dataset/train.csv"
#test_path = "/Users/rishabhjain/Documents/Bits-Pilani/Sem2/SEML/Health-Insurance-Cross-Sell-Prediction/dataset/test.csv"
#testResponse_path = "/Users/rishabhjain/Documents/Bits-Pilani/Sem2/SEML/Health-Insurance-Cross-Sell-Prediction/dataset/testResponse.csv"

df_train = pd.read_csv(train_path)
#df_test = pd.read_csv(test_path)
#df_testResponse = pd.read_csv(testResponse_path)

# %%
# Preview of the dataset
print("📊 Dataset information:")
print(f"Number of rows: {df_train.shape[0]:,}")
print(f"Number of columns: {df_train.shape[1]}")

print("\n" + "="*50)
print("📋 Columns:")
print("="*50)
for i, col in enumerate(df_train.columns, 1):
    print(f"{i}. {col}")

print("\n" + "="*50)
print("🔍 First 5 Rows:")
print("="*50)
print(df_train.head())

print("\n" + "="*50)
print("📈 Basic Statistics:")
print("="*50)
print(df_train.describe())

print("\n" + "="*50)
print("🎯 Target Variable Distribution (Response)")
print("="*50)
print(df_train['Response'].value_counts())
print("\nResponse Proportions:")
print(df_train['Response'].value_counts(normalize=True) * 100)
# Out:
# 📊 Dataset information:
# Number of rows: 381,109
# Number of columns: 12
#
# ...
# 📋 Columns:
# ...
# 1. id
# 2. Gender
# 3. Age
# 4. Driving_License
# 5. Region_Code
# 6. Previously_Insured
# 7. Vehicle_Age
# 8. Vehicle_Damage
# 9. Annual_Premium
# 10. Policy_Sales_Channel
# 11. Vintage
# 12. Response
#
# ...
# 🔍 First 5 Rows:
# ...
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# ...

# %%
# Missing values
print("🔍 Missing Values:")
print(df_train.isnull().sum())

# Data types
print("\n📝 Data Types:")
print(df_train.dtypes)

# Unique values (categorical için)
for col in df_train.select_dtypes(include='object').columns:
    print(f"\n{col}: {df_train[col].unique()}")
# Out:
# 🔍 Missing Values:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64
#
# 📝 Data Types:
# id                        int64
# Gender                      str
# Age                       int64
# Driving_License           int64
# Region_Code             float64
# Previously_Insured        int64
# Vehicle_Age                 str
# Vehicle_Damage              str
# Annual_Premium          float64
# Policy_Sales_Channel    float64
# Vintage                   int64
# Response                  int64
# dtype: object
#
# Gender: <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
#
# Vehicle_Age: <StringArray>
# ['> 2 Years', '1-2 Year', '< 1 Year']
# Length: 3, dtype: str
#
# ...
